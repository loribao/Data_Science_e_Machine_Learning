# %% [markdown]
# # Python

# %%
string = """Qual o caminho entre a Felicidade e a morte"""
display(string)

outraString = """O país {0} com {1}% de felicidade {2}% de suicidio """.format("Alemanha", 80, 20)
display(outraString.upper())
# Out:
# 'Qual o caminho entre a Felicidade e a morte'
# 'O PAÍS ALEMANHA COM 80% DE FELICIDADE 20% DE SUICIDIO '

# %%
my_list_to_be_sorted = ["uva", "maca", "banana", "pera"]
print(my_list_to_be_sorted)
# Out:
# ['uva', 'maca', 'banana', 'pera']

# %%
my_tuple = (1,2,3,4,5)
print(my_tuple)
# Out:
# (1, 2, 3, 4, 5)

# %%
dictionary = dict()
my_other_dict = {"one":1, "two":2, "three":3}
print(my_other_dict)
print(my_other_dict["one"])
print("one" in my_other_dict)

print(1 in my_other_dict)
# Out:
# {'one': 1, 'two': 2, 'three': 3}
# 1
# True
# False

# %%
if 2 > 1:
    print("Xgboost")
    
value = 10
if value <=10:
    print("That's a great deal!")
elif 10 <= value <=20:
    print("I'd still pay that...")
else:
    print("Wow! That's too much!")
# Out:
# Xgboost
# That's a great deal!

# %%
for number in range(20,40,5):
    print(number)
print("-----------------")
for number in [0,1,2,3,4]:
        print(number)
print("-----------------")
a_dict = {"one":1, "two":2, "three":3}
for key in a_dict:
    print(key)
# Out:
# 20
# 25
# 30
# 35
# -----------------
# 0
# 1
# 2
# 3
# 4
# -----------------
# one
# two
# three

# %%
i = 0
while i < 10:
        print(i)
        i = i + 2
    
pass
# Out:
# 0
# 2
# 4
# 6
# 8

# %%
my_dict = {"a":1, "b":2, "c":3}

try:
    value = my_dict["d"]
except KeyError:
    print(dir(KeyError))
# Out:
# ['__cause__', '__class__', '__context__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__', '__suppress_context__', '__traceback__', 'args', 'with_traceback']

# %%
handle = open("dataType.txt", "r")
data = handle.read()
print(data)
handle.close()
# Out:
# teste 123 Vamos

# %%
handle = open("dataType.txt", "r")

for line in handle:
    print(line)
    
handle.close()
# Out:
# teste 123 Vamos

# %%
handle = open("dataType.txt","r")

while True:
    data = handle.read(1024)
    print(data)
    if not data:
        break
# Out:
# teste 123 Vamos

# %%
with open("dataType.txt") as file_handler:
    for line in file_handler:
        print(line)
# Out:
# teste 123 Vamos

# %%
try:
    file_handler = open("test.txt")
    for line in file_handler:
        print(line)
except IOError:
    print("An IOError has occurred!")
finally:
    file_handler.close()
# Out:
# An IOError has occurred!

# %%
import math
math.sqrt(25)
# Out:
# 5.0

# %%
from math import sqrt
sqrt(2)
# Out:
# 1.4142135623730951

# %%
from math import *
sqrt(100)
# Out:
# 10.0

# %%
def mixed_function(a, b=2, c=3):
        return a+b+c
    
display(mixed_function(1, 4, 4))
# Out:
# 9

# %%
class dog (object):
    """docstring"""
    
    def _init_(self, color, breed, size, pedigree):
        """Constructor"""
        self.color = color
        self.breed = breed
        self.size = size
        self.pedigree = pedigree
        
    def premio(self):
        """
        Premium dog
        """
        
    return """Recive medal"""
        
if _name_ =="_main_":
    first = dog("white", "Lhasa Apso", "P", "Yes")
    print(first.dog)
    
    second = dog("black", "Podlee", "M", "Yes")
    print(second.dog)
# Out:
#   File "<ipython-input-48-451439c7640c>", line 16
#     return """Recive medal"""
#     ^
# SyntaxError: 'return' outside function

# %%
import sys
import os
print(os.getcwd())
# Out:
# C:\Users\rui.rperic

# %%
os.mkdir("pasta")

# %%
path = "C:\\Users\\rui.rperic\\pasta1\\pasta2\\pasta3"
os.makedirs(path)

# %%
os.rmdir("C:\\Users\\rui.rperic\\pasta1\\pasta2\\pasta3")

# %%
path = "C:\\Users\\rui.rperic"
for root, dirs, files in os.walk(path):
    print(root)
# Out:
# C:\Users\rui.rperic
# C:\Users\rui.rperic\.astah
# C:\Users\rui.rperic\.astah\community
# C:\Users\rui.rperic\.astah\community\plugins
# C:\Users\rui.rperic\.config
# C:\Users\rui.rperic\.config\configstore
# C:\Users\rui.rperic\.ipynb_checkpoints
# C:\Users\rui.rperic\.ipython
# C:\Users\rui.rperic\.ipython\extensions
# C:\Users\rui.rperic\.ipython\nbextensions
# C:\Users\rui.rperic\.ipython\profile_default
# C:\Users\rui.rperic\.ipython\profile_default\db
# C:\Users\rui.rperic\.ipython\profile_default\log
# C:\Users\rui.rperic\.ipython\profile_default\pid
# C:\Users\rui.rperic\.ipython\profile_default\security
# C:\Users\rui.rperic\.ipython\profile_default\startup
# C:\Users\rui.rperic\.vscode
# C:\Users\rui.rperic\.vscode\extensions
# C:\Users\rui.rperic\.vscode\extensions\coenraads.bracket-pair-colorizer-1.0.61
# C:\Users\rui.rperic\.vscode\extensions\coenraads.bracket-pair-colorizer-1.0.61\.github
# ...

# %%
import datetime
now = datetime.datetime.now()
print(now)
then = datetime.datetime(1984, 3, 25)
delta = now - then
type(delta)

print(delta.days)

print(delta.seconds)
# Out:
# 2019-11-12 21:56:58.504467
# 13015
# 79018

# %%
import pandas as pd

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
df = pd.DataFrame({'Aluno' : ["Wilfred", "Abbie", "Harry", "Julia", "Carrie","Jhonny", "Anthony"],
                   'Faltas' : [3,4,2,1,4,4,2],
                   'Provas' : [2,7,5,10,6,7,10],
                   'Seminario' : [8.5,7.5,9.0,7.5,8.0,9.0,7.5]})
print(df)
print("______________________")
print(df.dtypes)
print("______________________")
print(df.columns)
print("______________________")
print(df.describe())
print("______________________")
print(df.sort_values(by="Seminario"))
# Out:
#      Aluno  Faltas  Provas  Seminario
# 0  Wilfred       3       2        8.5
# 1    Abbie       4       7        7.5
# 2    Harry       2       5        9.0
# 3    Julia       1      10        7.5
# 4   Carrie       4       6        8.0
# 5   Jhonny       4       7        9.0
# 6  Anthony       2      10        7.5
# ______________________
# Aluno         object
# Faltas         int64
# Provas         int64
# Seminario    float64
# dtype: object
# ______________________
# Index(['Aluno', 'Faltas', 'Provas', 'Seminario'], dtype='object')
# ______________________
#          Faltas     Provas  Seminario
# count  7.000000   7.000000   7.000000
# mean   2.857143   6.714286   8.142857
# std    1.214986   2.811541   0.690066
# min    1.000000   2.000000   7.500000
# 25%    2.000000   5.500000   7.500000
# 50%    3.000000   7.000000   8.000000
# 75%    4.000000   8.500000   8.750000
# max    4.000000  10.000000   9.000000
# ______________________
#      Aluno  Faltas  Provas  Seminario
# ...

# %%
display(df)
print(df.loc[6])
# Out:
#      Aluno  Faltas  Provas  Seminario
# 0  Wilfred       3       2        8.5
# 1    Abbie       4       7        7.5
# 2    Harry       2       5        9.0
# 3    Julia       1      10        7.5
# 4   Carrie       4       6        8.0
# 5   Jhonny       4       7        9.0
# 6  Anthony       2      10        7.5
# Aluno        Anthony
# Faltas             2
# Provas            10
# Seminario        7.5
# Name: 6, dtype: object

# %%
display(df[(df["Provas"] >= 5) & (df["Faltas"] <= 2)])

display("ALUNOS APROVADOS!")

display(df[df["Faltas"] > 2])

display("ALUNOS REPROVADOS!")
# Out:
#      Aluno  Faltas  Provas  Seminario
# 2    Harry       2       5        9.0
# 3    Julia       1      10        7.5
# 6  Anthony       2      10        7.5
# 'ALUNOS APROVADOS!'
#      Aluno  Faltas  Provas  Seminario
# 0  Wilfred       3       2        8.5
# 1    Abbie       4       7        7.5
# 4   Carrie       4       6        8.0
# 5   Jhonny       4       7        9.0
# 'ALUNOS REPROVADOS!'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import Imputer
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import VarianceThreshold
from sklearn.feature_selection import SelectFromModel
from sklearn.utils import shuffle
from sklearn.ensemble import RandomForestClassifier

pd.set_option('display.max_columns', 100)

# %%
ds2015_df = pd.read_csv('C:\\Users\\rui.rperic\\Desktop\\DataSets\\ds2015.csv')
display(ds2015_df.head(n =10))
# Out:
#        Country                     Region  Happiness Rank  Happiness Score  \
# 0  Switzerland             Western Europe               1            7.587
# 1      Iceland             Western Europe               2            7.561
# 2      Denmark             Western Europe               3            7.527
# 3       Norway             Western Europe               4            7.522
# 4       Canada              North America               5            7.427
# 5      Finland             Western Europe               6            7.406
# 6  Netherlands             Western Europe               7            7.378
# 7       Sweden             Western Europe               8            7.364
# 8  New Zealand  Australia and New Zealand               9            7.286
# 9    Australia  Australia and New Zealand              10            7.284
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import Imputer
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import VarianceThreshold
from sklearn.feature_selection import SelectFromModel
from sklearn.utils import shuffle
from sklearn.ensemble import RandomForestClassifier

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
#_2016_df = pd.read_csv('C:\\Users\\rui.rperic\\ds2016.csv', sep=",")
#display(_2016_df.head(n =10))
ds2015_df = pd.read_csv('C:\\Users\\rui.rperic\\Desktop\\DataSets\\ds2015.csv')
print(ds2015_df.shape)
ds2016_df = pd.read_csv('C:\\Users\\rui.rperic\\Desktop\\DataSets\\ds2016.csv')
print(ds2016_df.shape)
ds2017_df = pd.read_csv('C:\\Users\\rui.rperic\\Desktop\\DataSets\\ds2017.csv')
print(ds2017_df.shape)
print("__________________________2015___________________________")
ds2015_df.info()
print("__________________________2016___________________________")
ds2016_df.info()
print("__________________________2017___________________________")
ds2017_df.info()
# Out:
# (158, 12)
# (157, 13)
# (155, 12)
# __________________________2015___________________________
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
# Country                          158 non-null object
# Region                           158 non-null object
# Happiness Rank                   158 non-null int64
# Happiness Score                  158 non-null float64
# Standard Error                   158 non-null float64
# Economy (GDP per Capita)         158 non-null float64
# Family                           158 non-null float64
# Health (Life Expectancy)         158 non-null float64
# Freedom                          158 non-null float64
# Trust (Government Corruption)    158 non-null float64
# Generosity                       158 non-null float64
# Dystopia Residual                158 non-null float64
# dtypes: float64(9), int64(1), object(2)
# memory usage: 14.9+ KB
# ...

# %%
v = meta[(meta.level == 'nominal') & (meta.keep)].index

for f in v:
    plt.figure()
    fig, ax = plt.subplots(figsize=(12,7))
    # Calculate the percentage of target=1 per category value
    cat_perc = ds2015_df [[f, 'target']].groupby([f],as_index=False).mean()
    cat_perc.sort_values(by='target', ascending=False, inplace=True)
    # Bar plot
    # Order the bars descending on target mean
    sns.barplot(ax=ax, x=f, y='target', data=cat_perc, order=cat_perc[f])
    plt.ylabel('% target', fontsize=18)
    plt.xlabel(f, fontsize=18)
    plt.tick_params(axis='both', which='major', labelsize=18)
    plt.show();
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-def9e0ddcddf> in <module>
# ----> 1 v = meta[(meta.level == 'nominal') & (meta.keep)].index
#       2
#       3 for f in v:
#       4     plt.figure()
#       5     fig, ax = plt.subplots(figsize=(12,7))
#
# NameError: name 'meta' is not defined

# %%
print(ds2015_df['Happiness Rank'].median())
# Out:
# 79.5

# %%
import pandas as pd# Read in data and examine first 10 rows
import matplotlib.pyplot as plt
import seaborn as sns

happy15 = pd.read_csv('C:\\Users\\rui.rperic\\Desktop\\DataSets\\ds2015.csv', sep = ',')

# plt.hist(happy15['Happiness Rank'], color = 'blue',
#          edgecolor = 'black',
#          bins = int(158/12))

sns.distplot(happy15['Happiness Rank'], hist=True, kde=False, 
             bins = int(158/12), color = 'blue',
             hist_kws={'edgecolor':'black'})

plt.title('Histograma de Paises / Felicidade')
# plt.xlabel('Felicidade')
# plt.ylabel('Paises')
# Out:
# Text(0.5, 1.0, 'Histograma de Paises / Felicidade')

# %%
sns.boxplot(y=happy15.Country, 
            orient = 'v')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-24e4aa210c95> in <module>
#       1 sns.boxplot(y=happy15.Country,
# ----> 2             orient = 'v')
#
# c:\programdata\miniconda3\lib\site-packages\seaborn\categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, notch, ax, **kwargs)
#    2235     kwargs.update(dict(whis=whis, notch=notch))
#    2236
# -> 2237     plotter.plot(ax, kwargs)
#    2238     return ax
#    2239
#
# c:\programdata\miniconda3\lib\site-packages\seaborn\categorical.py in plot(self, ax, boxplot_kws)
#     547     def plot(self, ax, boxplot_kws):
#     548         """Make the plot."""
# --> 549         self.draw_boxplot(ax, boxplot_kws)
#     550         self.annotate_axes(ax)
#     551         if self.orient == "h":
#
# ...
